# %% [markdown]
# <a href="https://colab.research.google.com/github/08Rohini/FMLLab/blob/main/plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode=[0.2,0,0,0]

plt.pie(y, labels = mylabels,explode=myexplode)
plt.show()

# %%
import numpy as np
c=np.random.normal(100,30,400)
plt.boxplot(c)
plt.show()
